# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx').set_index('index')
df.head()
# Out:
#        diameter  t_steel   D/t  bend_angle  SMYS  E1_CFRP  E2_CFRP  \
# index
# 0         114.3    5.715  20.0          12   358   138000     9000
# 1         114.3    5.715  20.0          12   358   138000     9000
# 2         114.3    5.715  20.0          12   358   138000     9000
# 3         114.3    5.715  20.0          12   358   138000     9000
# 4         114.3    5.715  20.0          12   358   138000     9000
#
#         alpha1_CFRP  alpha2_CFRP  L_CFRP  ...  fibre_orient  pressure  deltaT  \
# index                                     ...
# 0     -7.600000e-07     0.000036    1.73  ...             0     6.980      60
# 1     -7.600000e-07     0.000036    1.73  ...             1     6.980      60
# 2     -7.600000e-07     0.000036    1.73  ...             0     4.657      60
# 3     -7.600000e-07     0.000036    1.73  ...             0     2.230      60
# 4     -7.600000e-07     0.000036    1.48  ...             0     6.980      60
#
# ...
