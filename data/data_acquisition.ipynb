# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx', 'Combined').set_index('index')
df.dropna(inplace=True)

# %%
features_list = ['t_steel', 'D/t', 'L_CFRP', 't_CFRP', 'fibre_orient', 'pressure']
target_variable = ['No_CFRP_vm','peak_vm', 'peak_vm_CFRP', 'vm_reduction_perc']

# %%
df.shape
# Out:
# (249, 21)

# %%
df[features_list + target_variable].head(10)
# Out:
#        t_steel   D/t  L_CFRP  t_CFRP  fibre_orient  pressure  No_CFRP_vm  \
# index
# 0        5.715  20.0    1.73     1.0             0     6.980       431.2
# 1        5.715  20.0    1.73     1.0             1     6.980       431.2
# 2        5.715  20.0    1.73     1.0             0     4.657       424.9
# 3        5.715  20.0    1.73     1.0             0     2.230       418.6
# 4        5.715  20.0    1.48     1.0             0     6.980       431.2
# 5        5.715  20.0    1.48     1.0             1     6.980       431.2
# 6        5.715  20.0    1.48     1.0             0     4.657       424.9
# 7        5.715  20.0    1.48     1.0             0     2.230       418.6
# 8        5.715  20.0    1.23     1.0             0     6.980       431.2
# 9        5.715  20.0    1.23     1.0             1     6.980       431.2
#
#        peak_vm  peak_vm_CFRP  vm_reduction_perc
# index
# 0        412.7         365.1           4.290353
# 1        391.0         576.0           9.322820
# 2        408.0         335.1           3.977406
# 3        403.0         307.4           3.726708
# 4        413.6         364.2           4.081633
# 5        389.8         577.2           9.601113
# 6        409.0         335.2           3.742057
# 7        404.1         307.6           3.463927
# 8        412.9         362.8           4.243970
# 9        388.6         569.4           9.879406
